# %% [markdown]
# # Exploratory Data Analysis & Preprocessing
#
# In this notebook, we load the synthetic Indian Soil Health Card dataset, visualize the distribution of nutrients (NPK) and climate data, and prepare the dataset for our Machine Learning models.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set plotting style
sns.set_theme(style="whitegrid")

# Load the dataset
df = pd.read_csv('../data/soil_health_data.csv')
df.head()

# %% [markdown]
# ### Basic Dataset Information

# %%
df.info()
df.describe()

# %% [markdown]
# ### Distribution of Recommended Fertilizers

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, y='Recommended_Fertilizer', order=df['Recommended_Fertilizer'].value_counts().index)
plt.title('Distribution of Fertilizer Recommendations')
plt.xlabel('Count')
plt.ylabel('Fertilizer Type')
plt.show()
